# %%
from  matplotlib  import pyplot
from keras import backend as K
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# read and plot image using mpimg (image path: data_aug/meerkat.jpg)
img = mpimg.imread('data_aug/meerkat.jpg')
plt.imshow(img)

# %%
# use ImageDataGenerator from keras.preprocessing.image to generate different variations of the above image
from keras.preprocessing.image import ImageDataGenerator

# add your implementation

# %%
# datagen = ImageDataGenerator(
#     featurewise_center=True,
#     featurewise_std_normalization=True,
#     rotation_range=20,
#     width_shift_range=0.2,
#     height_shift_range=0.2,
#     horizontal_flip=True)

'''
  - `'theta'`: Float. Rotation angle in degrees.
        - `'tx'`: Float. Shift in the x direction.
        - `'ty'`: Float. Shift in the y direction.
        - `'shear'`: Float. Shear angle in degrees.
        - `'zx'`: Float. Zoom in the x direction.
        - `'zy'`: Float. Zoom in the y direction.
        - `'flip_horizontal'`: Boolean. Horizontal flip.
        - `'flip_vertical'`: Boolean. Vertical flip.
        - `'channel_shift_intencity'`: Float. Channel shift intensity.
        - `'brightness'`: Float. Brightness shift intensity.'''

img_transformed = ImageDataGenerator()
parameters={'tx':180, 'theta':45 }
aug_img = img_transformed.apply_transform(img, parameters)
plt.imshow(aug_img)

# %%
for X_batch, y_batch in datagen.flow(X_train, y_train, batch_size = )
